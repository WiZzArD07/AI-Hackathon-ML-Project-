# %%
print ("Hello Aryan, We are grateful to have you on board Let's enjoy and learn somethimg new.")
# Out:
# Hello Aryan, We are grateful to have you on board Let's enjoy and learn somethimg new.

# %%
a = 1
b = 1.0
c = 'a'
d = "word"
e = "i am a boy"
f = True
print(type(a),type(b),type(c),type(d),type(e),type(f))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'str'> <class 'str'> <class 'bool'>

# %%
name = input()
print(name)
print(type(name)) #data type always
a = input()
b = input()
add = a+b
print(add)
# Out:
# Aryan
# Aryan
# <class 'str'>
# 11
# 22
# 1122

# %%
# conditions
num = 12
remainder=num%2
if(remainder==0):
  print("it is an even no.")
else:
  print("odd no.")
# Out:
# it is an even no.

# %%
# weather conditions
con = input("enter the weather condition  ").lower()  #CASE SENSITIVE
if (con=="sunny"):
  print("summer season")
elif (con=="cold"):
  print("winter season")
elif con=="rain"or con=="thunder":
  print("monsoon season")
else:
  print("wrong data")
# Out:
# enter the weather condition  sunny
# summer season

# %%
#mutiplication table
n=int(input("enter a no."))
for i in range(1,11):
  print( F'{n} *  {i} = {i*n}')
# Out:
# enter a no.5
# 5 *  1 = 5
# 5 *  2 = 10
# 5 *  3 = 15
# 5 *  4 = 20
# 5 *  5 = 25
# 5 *  6 = 30
# 5 *  7 = 35
# 5 *  8 = 40
# 5 *  9 = 45
# 5 *  10 = 50

# %%
print("Aryan "*5)  #repetition
# Out:
# Aryan Aryan Aryan Aryan Aryan

# %%
age = int(input("enter your age"))

print(f'the age of {name} is {age}')
# Out:
# enter your age18
# the age of Aryan is 18

# %%
name="Aryan"
print(type(name))
age=19
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
i=5
while(i<=10):
  print(i,end="") #by default without end
  i+=1
# Out:
# 5678910

# %%
for i in range(10):
  print(i,end="")
# Out:
# 0123456789

# %%
#list and tupple
a = [5,10,15,20]
b = {5,10,15,20}
print(a)
print(type(a))
print(b)
print(type(b))
len(a)
# Out:
# [5, 10, 15, 20]
# <class 'list'>
# {10, 20, 5, 15}
# <class 'set'>
# 4

# %% [markdown]
# # New Section

# %%
# !pip install deepface opencv-python matplotlib

# %%
#!/usr/bin/env python
# coding: utf-8

# # Emotion Detection using DeepFace

# ### Packages

# In[22]:


from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt


# ### Loading and Displaying Input Image

# In[29]:


img1 = cv2.imread('img2.webp')
plt.imshow(img1[:,:,::-1])
plt.show()


# ### Deep Image Analysis

# In[30]:

result = DeepFace.analyze(img1, actions = ['emotion'])


# ### Formed Final Result

# In[31]:


print(result)


# In[ ]:
# Out:
# 24-12-02 10:56:15 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 50.7MB/s]
# [{'emotion': {'angry': 97.59469032287598, 'disgust': 3.581982932487904e-07, 'fear': 2.405310422182083, 'happy': 9.760246169414525e-15, 'sad': 2.913602137333271e-08, 'surprise': 2.6975555679996637e-13, 'neutral': 1.0756234492654925e-14}, 'dominant_emotion': 'angry', 'region': {'x': 413, 'y': 180, 'w': 213, 'h': 213, 'left_eye': (561, 268), 'right_eye': (472, 261)}, 'face_confidence': 0.91}]

# %%
#!/usr/bin/env python
# coding: utf-8

# # Emotion Detection using DeepFace

# ### Packages

# In[22]:


from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt


# ### Loading and Displaying Input Image

# In[29]:


img1 = cv2.imread('img3.webp')
plt.imshow(img1[:,:,::-1])
plt.show()


# ### Deep Image Analysis

# In[30]:

result = DeepFace.analyze(img1, actions = ['emotion'])


# ### Formed Final Result

# In[31]:


print(result)


# In[ ]:
# Out:
# [{'emotion': {'angry': 0.0007433303858944779, 'disgust': 3.788543928587176e-14, 'fear': 1.6059369799968134e-10, 'happy': 97.4676731267365, 'sad': 3.9528854762351283e-05, 'surprise': 0.0004784819223317913, 'neutral': 2.531064558796339}, 'dominant_emotion': 'happy', 'region': {'x': 438, 'y': 446, 'w': 183, 'h': 183, 'left_eye': (551, 509), 'right_eye': (486, 529)}, 'face_confidence': 0.9}]
